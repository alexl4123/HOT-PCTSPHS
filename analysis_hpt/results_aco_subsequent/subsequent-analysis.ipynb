# %% [markdown]
# # Subsequent analysis

# %%
import csv
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import math

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df_m_init = pd.read_csv("aco.csv")

# %%
df_m_init
# Out:
#           type                                       saw_policy  \
# 0    algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 1    algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 2    algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 3    algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 4    algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# ..         ...                                              ...
# 119  algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 120  algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 121  algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 122  algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 123  algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
#
#      population_size  random_k  alpha  beta   rho     p local_information  \
# 0                 50         5      1     1  0.24  0.50   objective_value
# 1                 50         5      1     1  0.24  0.25   objective_value
# 2                100         5      1     1  0.24  0.50   objective_value
# 3                100         5      1     1  0.24  0.25   objective_value
# 4                 50         5      1     1  0.24  0.50   objective_value
# ..               ...       ...    ...   ...   ...   ...               ...
# 119              100         5      1     1  0.24  0.25   objective_value
# 120               50         5      1     1  0.24  0.50   objective_value
# 121               50         5      1     1  0.24  0.25   objective_value
# 122              100         5      1     1  0.24  0.50   objective_value
# 123              100         5      1     1  0.24  0.25   objective_value
#
#      min_max_ant_system  termination_criterion  iteration      instance  \
# 0                  True                    200          0  rand_test_17
# 1                  True                    200          0  rand_test_17
# 2                  True                    200          0  rand_test_17
# 3                  True                    200          0  rand_test_17
# 4                  True                    200          1   rand_test_1
# ..                  ...                    ...        ...           ...
# 119                True                    200         29  rand_test_20
# 120                True                    200         30  rand_test_16
# 121                True                    200         30  rand_test_16
# 122                True                    200         30  rand_test_16
# 123                True                    200         30  rand_test_16
#
#          starting-time                                            fitness
# 0    20230103:14:01:32  [1523451307.7625;1523451307.7625;1523451307.76...
# 1    20230103:14:08:18  [1523452017.01875;1523452017.01875;1523452017....
# 2    20230103:14:22:39  [1523450554.3812501;1523450554.3812501;1523450...
# 3    20230103:14:35:51  [1523450871.2562501;1523450871.2562501;1523450...
# 4    20230103:14:42:43  [605315830.625;605315830.625;605315830.625;605...
# ..                 ...                                                ...
# 119  20230104:11:00:32  [769139813.5124999;769139813.5124999;769139813...
# 120  20230104:11:07:21  [3097377907.45;3097377907.45;3097377907.45;309...
# 121  20230104:11:15:05  [3097377388.38125;3097377388.38125;3097377388....
# 122  20230104:11:29:15  [3097378816.675;3097378816.675;3097378816.675;...
# 123  20230104:11:42:55  [3097378156.16875;3097378156.16875;3097378156....
#
# [124 rows x 15 columns]

# %%
data = df_m_init

# %%
iterations = list(data["iteration"])
iterations.sort() # Just to be safe
iterations = set(iterations)

# %%
average_scores = [0] * 4

for iteration in iterations:
    tmp_df = data[data["iteration"] == int(iteration)]
        
    fitness_lists = []
        
    for i in range(4):
        fitness_str = (tmp_df.iloc[i])["fitness"][1:len(list((tmp_df.iloc[i])["fitness"])) - 1]
        fitness_list = list(map(float, fitness_str.split(';')))
        fitness_list.sort()          
        
        fitness_lists.append(fitness_list)
        
    averages = []
    for fitness_list in fitness_lists:            
         averages.append(sum(fitness_list) / len(fitness_list))
            
    best_index = averages.index(max(averages))
    average_scores[best_index] += 1
    
    
    """
    if avg_first > avg_second:
        avg_score_first += 1
    else:
        avg_score_second += 1
    """
    

    
    
    
    #size_per_iteration.append(tmp_df.shape[0])
    #log_size_per_iteration.append(math.log(tmp_df.shape[0]))

# %%
average_scores
# Out:
# [11, 14, 1, 5]

# %%
data[data["iteration"] == 0]
# Out:
#         type                                       saw_policy  \
# 0  algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 1  algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 2  algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 3  algorithm  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
#
#    population_size  random_k  alpha  beta   rho     p local_information  \
# 0               50         5      1     1  0.24  0.50   objective_value
# 1               50         5      1     1  0.24  0.25   objective_value
# 2              100         5      1     1  0.24  0.50   objective_value
# 3              100         5      1     1  0.24  0.25   objective_value
#
#    min_max_ant_system  termination_criterion  iteration      instance  \
# 0                True                    200          0  rand_test_17
# 1                True                    200          0  rand_test_17
# 2                True                    200          0  rand_test_17
# 3                True                    200          0  rand_test_17
#
#        starting-time                                            fitness
# 0  20230103:14:01:32  [1523451307.7625;1523451307.7625;1523451307.76...
# 1  20230103:14:08:18  [1523452017.01875;1523452017.01875;1523452017....
# 2  20230103:14:22:39  [1523450554.3812501;1523450554.3812501;1523450...
# 3  20230103:14:35:51  [1523450871.2562501;1523450871.2562501;1523450...
