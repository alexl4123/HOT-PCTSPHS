# %% [markdown]
# # Subsequent analysis

# %%
import csv
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import math

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df_m_init = pd.read_csv("m_init.csv")

# %%
df_m_init
# Out:
#               type                                       saw_policy  \
# 0   initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 1   initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 2   initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 3   initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 4   initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 5   initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 6   initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 7   initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 8   initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 9   initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 10  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 11  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 12  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 13  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 14  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 15  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 16  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 17  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 18  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 19  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 20  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 21  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 22  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 23  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 24  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 25  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 26  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 27  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 28  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 29  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 30  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 31  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 32  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 33  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 34  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 35  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 36  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 37  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 38  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 39  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 40  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 41  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 42  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 43  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 44  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 45  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 46  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 47  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 48  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 49  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 50  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
# 51  initialization  Constant-Weights(Gamma-1:3;Gamma-2:3;Gamma-3:3)
#
#     termination_criterion  random_k  population_size  show_output  alpha  \
# 0                       0         5              100        False    0.5
# 1                       0         5              100        False    0.5
# 2                       0         5              100        False    0.5
# 3                       0         5              100        False    0.5
# 4                       0         5              100        False    0.5
# 5                       0         5              100        False    0.5
# 6                       0         5              100        False    0.5
# 7                       0         5              100        False    0.5
# 8                       0         5              100        False    0.5
# 9                       0         5              100        False    0.5
# 10                      0         5              100        False    0.5
# 11                      0         5              100        False    0.5
# 12                      0         5              100        False    0.5
# 13                      0         5              100        False    0.5
# 14                      0         5              100        False    0.5
# 15                      0         5              100        False    0.5
# 16                      0         5              100        False    0.5
# 17                      0         5              100        False    0.5
# 18                      0         5              100        False    0.5
# 19                      0         5              100        False    0.5
# 20                      0         5              100        False    0.5
# 21                      0         5              100        False    0.5
# 22                      0         5              100        False    0.5
# 23                      0         5              100        False    0.5
# 24                      0         5              100        False    0.5
# 25                      0         5              100        False    0.5
# 26                      0         5              100        False    0.5
# 27                      0         5              100        False    0.5
# 28                      0         5              100        False    0.5
# 29                      0         5              100        False    0.5
# 30                      0         5              100        False    0.5
# 31                      0         5              100        False    0.5
# 32                      0         5              100        False    0.5
# 33                      0         5              100        False    0.5
# 34                      0         5              100        False    0.5
# 35                      0         5              100        False    0.5
# 36                      0         5              100        False    0.5
# 37                      0         5              100        False    0.5
# 38                      0         5              100        False    0.5
# 39                      0         5              100        False    0.5
# 40                      0         5              100        False    0.5
# 41                      0         5              100        False    0.5
# 42                      0         5              100        False    0.5
# 43                      0         5              100        False    0.5
# 44                      0         5              100        False    0.5
# 45                      0         5              100        False    0.5
# 46                      0         5              100        False    0.5
# 47                      0         5              100        False    0.5
# 48                      0         5              100        False    0.5
# 49                      0         5              100        False    0.5
# 50                      0         5              100        False    0.5
# 51                      0         5              100        False    0.5
#
#     beta  gamma  delta  iteration      instance      starting-time  \
# 0     -1     -1    0.5          0   rand_test_8  20230103:13:12:56
# 1     -1     -1   -0.5          0   rand_test_8  20230103:13:15:50
# 2     -1     -1    0.5          1   rand_test_6  20230103:13:18:35
# 3     -1     -1   -0.5          1   rand_test_6  20230103:13:22:11
# 4     -1     -1    0.5          2  rand_test_18  20230103:13:25:09
# 5     -1     -1   -0.5          2  rand_test_18  20230103:13:28:13
# 6     -1     -1    0.5          3  rand_test_10  20230103:13:31:48
# 7     -1     -1   -0.5          3  rand_test_10  20230103:13:35:15
# 8     -1     -1    0.5          4   rand_test_4  20230103:13:38:22
# 9     -1     -1   -0.5          4   rand_test_4  20230103:13:41:35
# 10    -1     -1    0.5          5   rand_test_4  20230103:13:44:55
# 11    -1     -1   -0.5          5   rand_test_4  20230103:13:47:59
# 12    -1     -1    0.5          6  rand_test_17  20230103:13:51:32
# 14  [738830576.478999;738902727.1049991;738615902....
# 15  [738592811.2259989;738512903.4199989;738767665...
# 16  [1624123652.08;1623818308.766875;1623505054.92...
# 17  [1624059776.26875;1623860904.07625;1624138205....
# 18  [3062981761.1521864;3062675838.682438;30628205...
# 19  [3062690755.5560613;3062941920.670124;30627934...
# 20  [1488931018.5151248;1488794655.6746252;1488923...
# 21  [1488778583.4300625;1488777325.943938;14889680...
# 22  [560733573.3074368;561226344.5519993;560738217...
# 23  [560899316.6659993;560776896.5285618;560264801...
# 24  [1456889995.4465637;1456801351.014251;14568989...
# 25  [1457076232.0298135;1456834133.267501;14568907...
# 26  [3022823674.7176247;3022719813.5698757;3022629...
# 27  [3022216842.1641874;3022690602.541001;30223238...
# 28  [1646808794.3256273;1646808654.8511899;1647143...
# 29  [1646902991.1106904;1647098453.5545647;1646940...
# 30  [1406726484.941498;1406729471.4239979;14066775...
# 31  [1406353112.985498;1406913886.347748;140678971...
# 32  [3063056015.8618116;3063115800.3705616;3062924...
# 33  [3062996499.8073745;3062668066.2200603;3062708...
# 34  [736949903.7785618;736775947.3603123;737085767...
# 35  [736796920.1312499;736829177.8861873;736704251...
# 36  [609554837.1776876;609476421.3529999;609433759...
# 37  [609031718.8678751;609893666.7221874;609736476...
# 38  [1387460636.785627;1387418781.3740644;13871810...
# 39  [1387390779.6361895;1387380772.0042517;1387662...
# 40  [1623479059.878125;1624006577.311875;162375782...
# 41  [1623724918.468125;1623671930.779375;162348213...
# 42  [1456880140.8259385;1456856217.144313;14569807...
# 43  [1457134320.3358762;1456955313.9400635;1456941...
# 44  [530173653.178125;530247132.52875;530562920.88...
# 45  [530489703.120625;530891978.749375;530225103.3...
# 46  [1504522649.413999;1504809432.153874;150487336...
# 47  [1504884916.200874;1504822436.6167495;15051632...
# 48  [1593195002.5275;1593202486.58225;1593078414.2...
# 49  [1593178674.7982497;1593184425.33525;159321118...
# 50  [3062865767.6784363;3063026274.189124;30628657...
# 51  [3062745901.860186;3062755281.2693744;30627730...

# %%
data = df_m_init

# %%
iterations = list(data["iteration"])
iterations.sort() # Just to be safe
iterations = set(iterations)

# %%
score_first = 0
score_second = 0

avg_score_first = 0
avg_score_second = 0

for iteration in iterations:
    tmp_df = data[data["iteration"] == int(iteration)]
    
    first = tmp_df.iloc[0]
    second = tmp_df.iloc[1]
    
    
    if float(first["delta"]) == 0.5:
        first_option = first
        second_option = second
    else:
        first_option = second
        second_option = first
        
        
        
    first_option_str = first_option["fitness"][1:len(list(first_option["fitness"])) - 1]
    first_fitness_list = list(map(float, first_option_str.split(';')))
    first_fitness_list.sort()
    second_option_str = second_option["fitness"][1:len(list(second_option["fitness"])) - 1]
    second_fitness_list = list(map(float, second_option_str.split(';')))
    second_fitness_list.sort()
    
    
    
    for index in range(len(first_fitness_list)):
        if first_fitness_list[index] > second_fitness_list[index]:
            score_first += 1
        else:
            score_second += 1
            
    avg_first = sum(first_fitness_list) / len(first_fitness_list)
    avg_second = sum(second_fitness_list) / len(second_fitness_list)
    
    if avg_first > avg_second:
        avg_score_first += 1
    else:
        avg_score_second += 1

    

    
    
    
    #size_per_iteration.append(tmp_df.shape[0])
    #log_size_per_iteration.append(math.log(tmp_df.shape[0]))

# %%
print(score_first)
print(score_second)
# Out:
# 121
# 139

# %%
print(avg_score_first)
print(avg_score_second)
# Out:
# 14
# 12
